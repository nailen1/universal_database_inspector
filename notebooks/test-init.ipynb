# %%
from universal_database_inspector import init_structure, inspect_all, describe_all_tables, Table

# %%
init_structure()
# Out:
# initialized: /Users/juneyoungpark/dev/universal_database_inspector/database_structure
#   ├── labels/
#   └── description/
# '/Users/juneyoungpark/dev/universal_database_inspector/database_structure'

# %%
structure = inspect_all()
list(structure.keys())
# Out:
# ['bond', 'currency', 'daily_price', 'index', 'index_membership', 'stock_info']

# %%
describe_all_tables()
# Out:
# [1/6] skip (exists): bond
# [2/6] skip (exists): currency
# [3/6] skip (exists): daily_price
# [4/6] skip (exists): index
# [5/6] skip (exists): index_membership
# [6/6] skip (exists): stock_info
# done: 0 created, 6 skipped (total 6)
# ['/Users/juneyoungpark/dev/universal_database_inspector/database_structure/description/bond.json',
#  '/Users/juneyoungpark/dev/universal_database_inspector/database_structure/description/currency.json',
#  '/Users/juneyoungpark/dev/universal_database_inspector/database_structure/description/daily_price.json',
#  '/Users/juneyoungpark/dev/universal_database_inspector/database_structure/description/index.json',
#  '/Users/juneyoungpark/dev/universal_database_inspector/database_structure/description/index_membership.json',
#  '/Users/juneyoungpark/dev/universal_database_inspector/database_structure/description/stock_info.json']

# %%
table = Table('bond')
table

# %%
table.columns

# %%
table.labels

# %%
table.description

# %%
table.df

# %%
table.labeled
